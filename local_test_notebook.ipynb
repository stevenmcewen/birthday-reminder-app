# %%
import requests
import json

BASE_URL = "http://localhost:7071" 
endpoint = f"{BASE_URL}/api/test-daily-summary"
# endpoint = "https://func-rugbybot-dev-g9f5gygqhgcaepe4.southafricanorth-01.azurewebsites.net/api/IngestHistoricalKaggleResults"


print(f"Calling {endpoint} ...")
response = requests.post(endpoint)

print("Status:", response.status_code)
try:
    data = response.json()
    print("Response JSON:", json.dumps(data, indent=2))
except ValueError:
    print("Response text:", response.text)
# Out:
# Calling http://localhost:7071/api/DailyBirthdaySummaryTest ...
# Status: 404
# Response text:

# %%
import requests
import json

BASE_URL = "http://localhost:7071" 
endpoint = f"{BASE_URL}/api/test-monthly-summary"
# endpoint = "https://func-rugbybot-dev-g9f5gygqhgcaepe4.southafricanorth-01.azurewebsites.net/api/IngestHistoricalKaggleResults"


print(f"Calling {endpoint} ...")
response = requests.post(endpoint)

print("Status:", response.status_code)
try:
    data = response.json()
    print("Response JSON:", json.dumps(data, indent=2))
except ValueError:
    print("Response text:", response.text)
# Out:
# Calling http://localhost:7071/api/test-monthly-summary ...
# Status: 200
# Response JSON: {
#   "status": "ok",
#   "message": "MonthlyBirthdaySummaryFunction succeeded",
#   "system_event_id": "31f06059-7e96-433f-910b-0f6a7cf3d209",
#   "rows": 7,
#   "birthdays": [
#     {
#       "name": "Keegan Clark",
#       "birthday_day": 1,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
#     {
#       "name": "Janet Law",
#       "birthday_day": 12,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
#     {
#       "name": "Kiera Van Eeden",
#       "birthday_day": 15,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
#     {
#       "name": "Luke Planting",
#       "birthday_day": 15,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
#     {
#       "name": "Dad",
#       "birthday_day": 16,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
#     {
#       "name": "Robyn Hayward",
#       "birthday_day": 19,
#       "email_to": "stevenmcewen3@gmail.com"
#     },
# ...
